# %% [markdown]
# # Prerequirements
#
# To be able to run this colab correctly there are two things you need to setup before:
#
# - Make sure you are using a GPU environment, as a CPU wont be able to handle the processing required by the LLM. Due to the size of the model a GPU with at least 16GB of ram is required.
#
# - In the secrets section of the Colab, you must add a HuggingFace key with an account authorized to use Llama3 model of Meta:
#
#     1. You can accept Meta's agreement in [Llama3](https://huggingface.co/meta-llama/Meta-Llama-3-8B)
#     2. Once the agreement has been signed, and Meta has authorized you to use their models, you must proceed to obtain a HugginFace api token from the [Api Tokens Page](https://huggingface.co/settings/tokens)
#     3. You must set this api token as a secret on this Colab called `HF_TOKEN`, after which you should authorize it to be used on the Colab by checking the blue check.
#
# - This Colab uses Google Drive as a storing place. Thats why the variable defined on the first code execution called `DRIVE_FOLDER` should be fixed to point to the folder where the model will be saved.
#     - This folder must have the following structure:
#         - `Llama`: This folder will be used to store and retrieve the LLM.
#         - `Inputs`: This folder will contain all the json files meant to be processed. This will be a list of posts which each contains a list of comments too.
#             - `Inputs/IG`: Folder where the scrapped json files of instagram are.
#             - `Inputs/FB`: Folder where the scrapped json files of facebook are.
#             - `Inputs/Web`: Folder where the scrapped json files of the web are.
#         - `Chunks`: This folder is where the chunks of done processed data will be.
#         - `sentiment_output.json`: This will be the final output with the sentiment attached.

# %% [markdown]
# # Sentiment Analysis Model
#
# For the model, we will use Huggingface as an interface to easily access a variaty of models. Being allowed to fine tune them and test them in an efficient way.

# %% [markdown]
# ## Libraries installation and Module Imports

# %%
from google.colab import userdata, drive
drive.mount('/content/drive')
DRIVE_FOLDER="drive/MyDrive/Vero Volley project/SentimentModel"

# %%
# !pip install transformers
# !pip install datasets
# !pip install trl
# !pip install peft
# !pip install -q accelerate
# !pip install -q -i https://pypi.org/simple/ bitsandbytes
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.40.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Collecting datasets
#   Downloading datasets-2.19.1-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 10.5 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Collecting huggingface-hub>=0.21.2 (from datasets)
#   Downloading huggingface_hub-0.23.0-py3-none-any.whl (401 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, multiprocess, huggingface-hub, datasets
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# Successfully installed datasets-2.19.1 dill-0.3.8 huggingface-hub-0.23.0 multiprocess-0.70.16 xxhash-3.4.1
# Collecting trl
#   Downloading trl-0.8.6-py3-none-any.whl (245 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.2/245.2 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from trl) (2.2.1+cu121)
# Requirement already satisfied: transformers>=4.31.0 in /usr/local/lib/python3.10/dist-packages (from trl) (4.40.2)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.10/dist-packages (from trl) (1.25.2)
# Collecting accelerate (from trl)
#   Downloading accelerate-0.30.0-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.4/302.4 kB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from trl) (2.19.1)
# Collecting tyro>=0.5.11 (from trl)
#   Downloading tyro-0.8.3-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.0/102.0 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.4.0->trl)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.4.0->trl)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.4.0->trl)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.4.0->trl)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.4.0->trl)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.4.0->trl)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.4.0->trl)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.4.0->trl)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.4.0->trl)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.4.0->trl)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.4.0->trl)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.4.0->trl)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl) (0.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl) (4.66.4)
# Requirement already satisfied: docstring-parser>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl) (13.7.1)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl)
#   Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->trl) (5.9.5)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (2.0.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (3.9.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->trl) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->trl) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->trl) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->trl) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4.0->trl) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->trl) (1.16.0)
# Installing collected packages: shtab, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, tyro, nvidia-cusolver-cu12, accelerate, trl
# Successfully installed accelerate-0.30.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 shtab-1.7.1 trl-0.8.6 tyro-0.8.3
# Collecting peft
#   Downloading peft-0.10.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from peft) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from peft) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from peft) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft) (2.2.1+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from peft) (4.40.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from peft) (4.66.4)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from peft) (0.30.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from peft) (0.4.3)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from peft) (0.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (2023.12.25)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (0.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->peft) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->peft) (1.3.0)
# Installing collected packages: peft
# Successfully installed peft-0.10.0
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 8.3 MB/s eta 0:00:00

# %% [markdown]
# ## Models
#
# For the models, we will mainly focus on LLama3 and Gemma (Meta and Google LLM). This will be trained against a dataset of pre-classified tweet messages for defining if a message is either "positive", "neutral" or "negative".
#
# Other models already pre-tuned are already disponible, but based on Bert (old Google model).

# %%
# Models
model_gemma = "google/gemma-2b"
model_gemma_7b = "google/gemma-7b"
model_llama = "meta-llama/Meta-Llama-3-8B"
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import os
from tqdm import tqdm
import json

import torch
import torch.nn as nn

import transformers
from transformers import (AutoModelForCausalLM,
                          AutoTokenizer,
                          BitsAndBytesConfig,
                          TrainingArguments,
                          pipeline,
                          logging)
from datasets import Dataset, load_dataset
from peft import LoraConfig, PeftConfig
import bitsandbytes as bnb
from trl import SFTTrainer

from sklearn.metrics import (accuracy_score,
                             classification_report,
                             confusion_matrix)
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Model Initialization
#
# The model is initialized with specific paramethers for the optimization of the sentiment analysis.
#
# In specific, we load:
# - The model with the byte rules.
# - The tokenizer with the limit of characters to generate.
# - The End-Of-Sequence Token, to define where to stop the text generation.

# %%
model_name = model_llama
tokenizer_model_name = model_name

# Use Pretrained model
model_name = f"./{DRIVE_FOLDER}/Llama"

max_seq_length = 2048
tokenizer = AutoTokenizer.from_pretrained(tokenizer_model_name, max_seq_length=max_seq_length)
EOS_TOKEN = tokenizer.eos_token

compute_dtype = getattr(torch, "float16")

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=False,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    quantization_config=bnb_config,
)

model.config.use_cache = False
model.config.pretraining_tp = 1

tokenizer.pad_token = tokenizer.eos_token
tokenizer.pad_token_id = tokenizer.eos_token_id
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/177 [00:00<?, ?B/s]

# %% [markdown]
# ## Training & Testing
#
# We start defining the prompt for both training and testing. This defines the task to complete to the LLM, allowing a classification on the specific sentiments.

# %%
def generate_prompt(data_point):
    return (
        f"""generate_prompt
            Analyze the sentiment of the news headline enclosed in square brackets,
            determine if it is positive, neutral, or negative, and return the answer as
            the corresponding sentiment label "positive" or "neutral" or "negative"

            [{data_point["text"]}] = {data_point["label_text"]}
            """.strip()
        + EOS_TOKEN
    )

def generate_test_prompt(data_point):
    text = data_point
    if not isinstance(data_point, str):
        text = data_point["text"]

    return f"""Analyze the sentiment of the news headline enclosed in square brackets,
            determine if it is positive, neutral, or negative, and return the answer as
            the corresponding sentiment label "positive" or "neutral" or "negative"

            [{text}] =""".strip()

# %% [markdown]
# ### Evaluation
#
# We create the evaluation function, to compare and analyse the difference between the true emotions from the predicted emotions by the model. It defines a performance view of the model.

# %%
def evaluate(y_true, y_pred):
    print()
    labels = ['positive', 'neutral', 'negative']
    mapping = {'positive': 2, 'neutral': 1, 'none':1, 'negative': 0}
    def map_func(x):
        return mapping.get(x, 1)

    y_true = np.vectorize(map_func)(y_true)
    y_pred = np.vectorize(map_func)(y_pred)

    # Calculate accuracy
    accuracy = accuracy_score(y_true=y_true, y_pred=y_pred)
    print(f'Accuracy: {accuracy:.3f}')

    # Generate accuracy report
    unique_labels = set(y_true)  # Get unique labels

    for label in unique_labels:
        label_indices = [i for i in range(len(y_true))
                         if y_true[i] == label]
        label_y_true = [y_true[i] for i in label_indices]
        label_y_pred = [y_pred[i] for i in label_indices]
        accuracy = accuracy_score(label_y_true, label_y_pred)
        print(f'Accuracy for label {label}: {accuracy:.3f}')

    # Generate classification report
    class_report = classification_report(y_true=y_true, y_pred=y_pred)
    print('\nClassification Report:')
    print(class_report)

    # Generate confusion matrix
    conf_matrix = confusion_matrix(y_true=y_true, y_pred=y_pred, labels=[0, 1, 2])
    print('\nConfusion Matrix:')
    print(conf_matrix)

# %% [markdown]
# ### Parallelization Helper Functions
#
# We define some helper functions to be able to parallelize the prediction of files

# %% [markdown]
# #### Parallelization data conversion
#
# For being able to run a big list of files in parallel with multiple colab sessions, we created a new data structure that stores "elements" instead of posts with comments.
#
# An element, is simply either a post or a comment that is meant to be used to predict its sentiment. is composed by the following structure:
# ```python
# {
#   "hash": "g23hf..." # Is a hash representation of the post or element, to be interconnected later
#   "text": "I dunno, wh..." # The text that needs to be used for prediction
#   "sentiment": "negative" # The sentiment, if it was already predicted, if not None
# }
# ```

# %%
def post_to_hash(post):
  return f"{post.get('taken_at_date')}{post.get('date')}{post.get('title')}{post.get('content')}"

def comment_to_hash(post_hash, comment):
  return f"{post_hash}{comment.get('text')}{comment.get('author')}{comment.get('user')}{comment.get('username')}{comment.get('created_at_utc')}{comment.get('date')}"

# %%
def posts_to_elements(posts):
  elements = []
  seen_set = set()

  for post in posts:
    post_hash = post_to_hash(post)
    if post_hash not in seen_set:
      elements.append({
          "hash": post_hash,
          "text": post["title"] if post["title"] else post["content"],
          "sentiment": post["sentiment"] if "sentiment" in post else None
      })
      seen_set.add(post_hash)
      for comment in post["comments"]:
        comment_hash = comment_to_hash(post_hash, comment)
        if comment_hash not in seen_set:
          elements.append({
            "hash": comment_hash,
            "text": comment["text"],
            "sentiment": comment["sentiment"] if "sentiment" in comment else None
          })
          seen_set.add(comment_hash)

  return elements


def elements_to_posts(elements):
  # Platforms to check
  platform_to_separator = {
      "FB": "keyword",
      "IG": "keyword",
      "Web": "keyword"
  }
  # Open posts already analyzed, if not present initialize to empty array
  sentiment_from_element = {}
  seen_set = set()

  for element in elements:
    sentiment_from_element[element["hash"]] = element["sentiment"]


  # Crawl folders to find the files and posts
  posts = []
  platforms = next(os.walk(f'{DRIVE_FOLDER}/Inputs'))[1]
  for platform in platforms:
    if platform not in platform_to_separator:
      continue
    folder_files = next(os.walk(f'{DRIVE_FOLDER}/Inputs/{platform}'))[2]
    folder_files = list(filter(lambda x: (x.split(".")[-1] == "json"), folder_files))

    for filename in folder_files:
      source = filename.split(f"_{platform_to_separator[platform]}")[0]
      with open(f"{DRIVE_FOLDER}/Inputs/{platform}/{filename}", "r") as f:
        data = json.load(f)

      for post in data:
        post["platform"] = platform
        post["source"] = source
        post["title"] = post["title"] if post.get("title") else ""
        post["content"] = post["content"] if post.get("content") else ""
        post["comments"] = post["comments"] if post.get("comments") else []

        post_hash = post_to_hash(post)
        # Skip posts still not analyzed
        if post_hash in sentiment_from_element and post_hash not in seen_set:
          post["sentiment"] = sentiment_from_element[post_hash]
          del sentiment_from_element[post_hash]

          comments = []
          for comment in post["comments"]:
            comment_hash = comment_to_hash(post_hash, comment)

            # Skip comments still not analyzed
            if comment_hash in sentiment_from_element and comment_hash not in seen_set:
              comment["sentiment"] = sentiment_from_element[comment_hash]
              del sentiment_from_element[comment_hash]
              comments.append(comment)
              # seen_set.add(comment_hash)
          post["comments"] = comments

          posts.append(post)
          seen_set.add(post_hash)

  return posts

# %% [markdown]
# #### Data Fetching for parallelization
#
# Now, we fetch the data to fetch from the drive, we cross compare with the results already done and get a list of elements "to-do".
#
# This elements are shuffled so there are less probabilities of repeating processing of elements between multiple colab sessions.

# %%
import json
import os
import random

def thousands(number):
  return '{:,}'.format(number).replace(',','.')
def count_elements(posts):
  return len(posts) + sum(map(lambda x: len(x["comments"]), posts))
def count_format_elements(posts):
  return thousands(count_elements(posts))

def merge_chunks():
  set_to_skip = set()

  done_elements = []
  chunk_files = next(os.walk(f'{DRIVE_FOLDER}/Chunks'))[2]
  for chunk_file in chunk_files:
    if "done" not in chunk_file:
      continue

    try:
      with open(f'{DRIVE_FOLDER}/Chunks/{chunk_file}', "r") as f:
        chunk_data = json.load(f)
      for element in chunk_data:
        hash = element["hash"]
        if hash not in set_to_skip:
          done_elements.append(element)
          set_to_skip.add(hash)
    except:
      pass

  return done_elements, set_to_skip




def get_pair_of_data(with_print=True):
  # Platforms to check
  platform_to_separator = {
      "FB": "crawl",
      "IG": "post",
      "Web": "output"
  }
  # Open posts already analyzed, if not present initialize to empty array
  data_done, set_to_skip = merge_chunks()

  # Crawl folders to find the files and posts
  elements_to_process = []
  platforms = next(os.walk(f'{DRIVE_FOLDER}/Inputs'))[1]
  for platform in platforms:
    if platform not in platform_to_separator:
      continue
    folder_files = next(os.walk(f'{DRIVE_FOLDER}/Inputs/{platform}'))[2]
    folder_files = list(filter(lambda x: (x.split(".")[-1] == "json"), folder_files))

    for filename in folder_files:
      source = filename.split(f"_{platform_to_separator[platform]}")[0]
      with open(f"{DRIVE_FOLDER}/Inputs/{platform}/{filename}", "r") as f:
        data = json.load(f)

      for post in data:
        post["platform"] = platform
        post["source"] = source
        post["title"] = post["title"] if post.get("title") else ""
        post["content"] = post["content"] if post.get("content") else ""
        post["comments"] = post["comments"] if post.get("comments") else []

        post_hash = post_to_hash(post)

        # Skip posts already analyzed
        if post_hash not in set_to_skip:
          elements_to_process.append({
              "hash": post_hash,
              "text": post["title"] if post["title"] else post["content"],
              "sentiment": None
          })
          set_to_skip.add(post_hash)

        for comment in post["comments"]:
          comment_hash = comment_to_hash(post_hash, comment)
          if comment_hash not in set_to_skip:
            elements_to_process.append({
                "hash": comment_hash,
                "text": comment["text"],
                "sentiment": None
            })
            set_to_skip.add(comment_hash)

  random.shuffle(elements_to_process)

  # Number of elements to process (posts + comments)
  print("Elements to process:", thousands(len(elements_to_process)))
  print("Elements Skept:", thousands(len(data_done)))
  print()
  return elements_to_process, data_done

# %% [markdown]
# ### Prediction
#
# We define the prediction function, which uses the model to generate a prediction to a set of messages.

# %%
from google.colab import files
import uuid

"""
  Function for predicting a list of texts with the model
"""
def predict(X_test, model, tokenizer):
    y_pred = []
    for i in tqdm(range(len(X_test))):
        prompt = X_test.iloc[i]["text"]
        input_ids = tokenizer(prompt, return_tensors="pt").to("cuda")
        outputs = model.generate(**input_ids, max_new_tokens=1, temperature=0.001, pad_token_id = tokenizer.eos_token_id)
        result = tokenizer.decode(outputs[0])
        answer = result.split("=")[-1].lower()
        if "positive" in answer:
            y_pred.append("positive")
        elif "negative" in answer:
            y_pred.append("negative")
        elif "neutral" in answer:
            y_pred.append("neutral")
        else:
            y_pred.append("non-related")
    return y_pred

"""
  Adapter function to predict a json file of posts and comments
"""
def predict_json(json_data, model, tokenizer, data_to_append=[], chunk_index=0, debug=False):
    # List to collect all texts
    texts = []

    # Iterate over each post and its comments
    json_data = [*json_data]
    for post in json_data:
        # Append the post caption text
        try:
          texts.append(generate_test_prompt(post["title"] if post["title"] else post["content"]))
        except:
          print(post)
          raise Exception(":noooo")
        # Append each comment text
        for comment in post['comments']:
            texts.append(generate_test_prompt(comment["text"]))

    y_pred = []
    if len(texts) > 0:
      # Convert the list of texts into a DataFrame in one go
      df = pd.DataFrame(texts, columns=['text'])
      # Predict emotions
      y_pred = predict(df, model, tokenizer)

    # Assign emotion to posts and comments
    index = 0
    for post in json_data:
        post["sentiment"] = y_pred[index]
        index += 1
        if index < 40 and debug:
            print("-"*30)
            print(f"\n{post['sentiment']}: {post['title'] if post['title'] else post['content']}")
        for comment in post["comments"]:
            comment["sentiment"] = y_pred[index]
            index += 1
            if index < 40 and debug:
                print(f"  {comment['sentiment']}: {comment['text']}")

    checkpoint_filename = f"sentiment_output_[{chunk_index}]_{uuid.uuid4()}.json"
    with open(f"{DRIVE_FOLDER}/Chunks/{checkpoint_filename}", "w") as f:
        json.dump(json_data, f, indent=2)

    # Save output
    for post in data_to_append:
        json_data.append(post)

    with open("sentiment_output.json", "w") as f:
        json.dump(json_data, f, indent=2)
    return json_data

"""
  Function for predicting a list of elements, prebuilt for parallelization
"""
def predict_elements(elements_to_process, model, tokenizer, data_to_append=[], chunk_index=0, debug=False):
    # List to collect all texts
    texts = []

    # Iterate over each element
    elements_to_process = [*elements_to_process]
    for element in elements_to_process:
        texts.append(generate_test_prompt(element["text"]))

    y_pred = []
    if len(texts) > 0:
      # Convert the list of texts into a DataFrame in one go
      df = pd.DataFrame(texts, columns=['text'])
      # Predict emotions
      y_pred = predict(df, model, tokenizer)

    # Assign emotion to posts and comments
    index = 0
    for element in elements_to_process:
        element["sentiment"] = y_pred[index]
        index += 1

    checkpoint_filename = f"done_[{chunk_index}]_{uuid.uuid4()}.json"
    with open(f"{DRIVE_FOLDER}/Chunks/{checkpoint_filename}", "w") as f:
        json.dump(elements_to_process, f, indent=2)

    # Save output
    seen_set = set()
    for element in elements_to_process:
        seen_set.add(element["hash"])
    for element in data_to_append:
        if element["hash"] not in seen_set:
            elements_to_process.append(element)
            seen_set.add(element["hash"])

    return elements_to_process

# %% [markdown]
# #### Predict sentiment from list of posts and comments of json
#
# This function cares about the conversion of the list of posts and comments obtained as input from the Drive folder. It converts them into elements, and goes fetching them 500 elements at a time.
#
# On each iteration, it saves the results into chunks of done data, which is further used to avoid these elements on all colab sessions.

# %%
import time

elements_to_process, data_done = get_pair_of_data()

def chunks(lst, n):
    """Yield successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

elements_to_do = len(elements_to_process)
elements_done = 0
index = 0

STEPS = 500

start_time = time.perf_counter()
# Predict and save output of posts and comments from json
while len(elements_to_process) > 0:
  total_seconds = round(time.perf_counter() - start_time)
  hours = total_seconds // 3600
  minutes = (total_seconds - hours * 3600) // 60
  seconds = (total_seconds - hours * 3600 - minutes * 60)
  percentage_done = (elements_done * 1000 // len(elements_to_process)) / 10

  print(f"Iteration {index}: ({percentage_done}%) {hours}h {minutes}m {seconds}s")

  data_done = predict_json(elements_to_process[:STEPS], model, tokenizer, data_done, index)

  elements_done += STEPS

  print(f"  Done Elements: {thousands(elements_done)}")
  print(f"  Missing Elements: {thousands(elements_to_do - elements_done)}")
  print()

  # Get updated data
  elements_to_process, new_data_done = get_pair_of_data(False)
  seen_set = set()
  for data in data_done:
    seen_set.add(data["hash"])
  for element in new_data_done:
    if element["hash"] not in seen_set:
      data_done.append(element)
      seen_set.add(element["hash"])

  index += 1
# Out:
# Posts: 2.021
# Elements to process: 105.643
# Posts Skept: 9.420
# Elements Skept: 39.541
#
# Iteration 0: (0.0%) 0h 0m 0s
#   Using 3 Posts; Elements: 613
# 100%|██████████| 613/613 [03:11<00:00,  3.21it/s]
#   Done 3 Posts; Elements: 613
#   Missing 2.018 Posts; Elements: 105.030
#
# Iteration 1: (0.5%) 0h 3m 12s
#   Using 3 Posts; Elements: 258
# 100%|██████████| 258/258 [01:18<00:00,  3.30it/s]
#   Done 6 Posts; Elements: 871
#   Missing 2.015 Posts; Elements: 104.772
#
# Iteration 2: (0.8%) 0h 4m 31s
#   Using 3 Posts; Elements: 30
# 100%|██████████| 30/30 [00:08<00:00,  3.43it/s]
#   Done 9 Posts; Elements: 901
#   Missing 2.012 Posts; Elements: 104.742
#
# Iteration 3: (0.8%) 0h 4m 40s
#   Using 3 Posts; Elements: 44
# 100%|██████████| 44/44 [00:12<00:00,  3.45it/s]
#   Done 12 Posts; Elements: 945
#   Missing 2.009 Posts; Elements: 104.698
#
# Iteration 4: (0.8%) 0h 4m 54s
#   Using 3 Posts; Elements: 11
# 100%|██████████| 11/11 [00:03<00:00,  3.21it/s]
#   Done 15 Posts; Elements: 956
#   Missing 2.006 Posts; Elements: 104.687
#
# Iteration 5: (0.9%) 0h 4m 58s
#   Using 3 Posts; Elements: 270
# 100%|██████████| 270/270 [01:20<00:00,  3.35it/s]
#   Done 18 Posts; Elements: 1.226
#   Missing 2.003 Posts; Elements: 104.417
#
# Iteration 6: (1.1%) 0h 6m 20s
#   Using 3 Posts; Elements: 506
# 100%|██████████| 506/506 [02:37<00:00,  3.21it/s]
#   Done 21 Posts; Elements: 1.732
#   Missing 2.000 Posts; Elements: 103.911
#
# Iteration 7: (1.6%) 0h 8m 58s
#   Using 3 Posts; Elements: 797
# 100%|██████████| 797/797 [04:01<00:00,  3.30it/s]
#   Done 24 Posts; Elements: 2.529
#   Missing 1.997 Posts; Elements: 103.114
#
# Iteration 8: (2.3%) 0h 13m 0s
#   Using 3 Posts; Elements: 54
# 100%|██████████| 54/54 [00:16<00:00,  3.36it/s]
#   Done 27 Posts; Elements: 2.583
#   Missing 1.994 Posts; Elements: 103.060
#
# Iteration 9: (2.4%) 0h 13m 17s
#   Using 3 Posts; Elements: 49
# 100%|██████████| 49/49 [00:14<00:00,  3.45it/s]
#   Done 30 Posts; Elements: 2.632
#   Missing 1.991 Posts; Elements: 103.011
#
# Iteration 10: (2.4%) 0h 13m 33s
#   Using 3 Posts; Elements: 19
# 100%|██████████| 19/19 [00:05<00:00,  3.30it/s]
#   Done 33 Posts; Elements: 2.651
#   Missing 1.988 Posts; Elements: 102.992
#
# Iteration 11: (2.5%) 0h 13m 39s
#   Using 3 Posts; Elements: 14
# 100%|██████████| 14/14 [00:04<00:00,  3.29it/s]
#   Done 36 Posts; Elements: 2.665
#   Missing 1.985 Posts; Elements: 102.978
#
# Iteration 12: (2.5%) 0h 13m 44s
#   Using 3 Posts; Elements: 14
# 100%|██████████| 14/14 [00:04<00:00,  3.30it/s]
#   Done 39 Posts; Elements: 2.679
#   Missing 1.982 Posts; Elements: 102.964
#
# Iteration 13: (2.5%) 0h 13m 49s
#   Using 3 Posts; Elements: 16
# 100%|██████████| 16/16 [00:04<00:00,  3.39it/s]
#   Done 42 Posts; Elements: 2.695
#   Missing 1.979 Posts; Elements: 102.948
#
# Iteration 14: (2.5%) 0h 13m 55s
#   Using 3 Posts; Elements: 9
# 100%|██████████| 9/9 [00:02<00:00,  3.17it/s]
#   Done 45 Posts; Elements: 2.704
#   Missing 1.976 Posts; Elements: 102.939
#
# Iteration 15: (2.5%) 0h 13m 59s
#   Using 3 Posts; Elements: 10
# 100%|██████████| 10/10 [00:03<00:00,  3.19it/s]
#   Done 48 Posts; Elements: 2.714
#   Missing 1.973 Posts; Elements: 102.929
#
# Iteration 16: (2.5%) 0h 14m 2s
#   Using 3 Posts; Elements: 8
# 100%|██████████| 8/8 [00:02<00:00,  3.16it/s]
#   Done 51 Posts; Elements: 2.722
#   Missing 1.970 Posts; Elements: 102.921
#
# Iteration 17: (2.5%) 0h 14m 6s
#   Using 3 Posts; Elements: 13
# 100%|██████████| 13/13 [00:04<00:00,  3.15it/s]
#   Done 54 Posts; Elements: 2.735
#   Missing 1.967 Posts; Elements: 102.908
#
# Iteration 18: (2.5%) 0h 14m 10s
#   Using 3 Posts; Elements: 37
# 100%|██████████| 37/37 [00:10<00:00,  3.47it/s]
#   Done 57 Posts; Elements: 2.772
#   Missing 1.964 Posts; Elements: 102.871
#
# Iteration 19: (2.6%) 0h 14m 22s
#   Using 3 Posts; Elements: 18
# 100%|██████████| 18/18 [00:05<00:00,  3.32it/s]
#   Done 60 Posts; Elements: 2.790
#   Missing 1.961 Posts; Elements: 102.853
#
# Iteration 20: (2.6%) 0h 14m 28s
#   Using 3 Posts; Elements: 13
# 100%|██████████| 13/13 [00:03<00:00,  3.28it/s]
#   Done 63 Posts; Elements: 2.803
#   Missing 1.958 Posts; Elements: 102.840
#
# Iteration 21: (2.6%) 0h 14m 33s
#   Using 3 Posts; Elements: 10
# 100%|██████████| 10/10 [00:03<00:00,  3.32it/s]
#   Done 66 Posts; Elements: 2.813
#   Missing 1.955 Posts; Elements: 102.830
#
# Iteration 22: (2.6%) 0h 14m 37s
#   Using 3 Posts; Elements: 6
# 100%|██████████| 6/6 [00:01<00:00,  3.32it/s]
#   Done 69 Posts; Elements: 2.819
#   Missing 1.952 Posts; Elements: 102.824
#
# Iteration 23: (2.6%) 0h 14m 40s
#   Using 3 Posts; Elements: 50
# 100%|██████████| 50/50 [00:14<00:00,  3.50it/s]
#   Done 72 Posts; Elements: 2.869
#   Missing 1.949 Posts; Elements: 102.774
#
# Iteration 24: (2.7%) 0h 14m 55s
#   Using 3 Posts; Elements: 6
# 100%|██████████| 6/6 [00:02<00:00,  2.99it/s]
#   Done 75 Posts; Elements: 2.875
#   Missing 1.946 Posts; Elements: 102.768
#
# Iteration 25: (2.7%) 0h 14m 58s
#   Using 3 Posts; Elements: 3
# 100%|██████████| 3/3 [00:01<00:00,  2.28it/s]
#   Done 78 Posts; Elements: 2.878
#   Missing 1.943 Posts; Elements: 102.765
#
# Iteration 26: (2.7%) 0h 15m 0s
#   Using 3 Posts; Elements: 6
# 100%|██████████| 6/6 [00:02<00:00,  2.93it/s]
#   Done 81 Posts; Elements: 2.884
#   Missing 1.940 Posts; Elements: 102.759
#
# Iteration 27: (2.7%) 0h 15m 3s
#   Using 3 Posts; Elements: 3
# 100%|██████████| 3/3 [00:01<00:00,  2.47it/s]
#   Done 84 Posts; Elements: 2.887
#   Missing 1.937 Posts; Elements: 102.756
#
# Iteration 28: (2.7%) 0h 15m 5s
#   Using 3 Posts; Elements: 3
# 100%|██████████| 3/3 [00:01<00:00,  2.41it/s]
#   Done 87 Posts; Elements: 2.890
#   Missing 1.934 Posts; Elements: 102.753
#
# Iteration 29: (2.7%) 0h 15m 7s
#   Using 3 Posts; Elements: 4
# 100%|██████████| 4/4 [00:01<00:00,  2.45it/s]
#   Done 90 Posts; Elements: 2.894
#   Missing 1.931 Posts; Elements: 102.749
#
# Iteration 30: (2.7%) 0h 15m 9s
#   Using 3 Posts; Elements: 3
# 100%|██████████| 3/3 [00:01<00:00,  2.35it/s]
#   Done 93 Posts; Elements: 2.897
#   Missing 1.928 Posts; Elements: 102.746
#
# Iteration 31: (2.7%) 0h 15m 11s
#   Using 3 Posts; Elements: 7
# 100%|██████████| 7/7 [00:02<00:00,  2.78it/s]
#   Done 96 Posts; Elements: 2.904
#   Missing 1.925 Posts; Elements: 102.739
#
# Iteration 32: (2.7%) 0h 15m 15s
#   Using 3 Posts; Elements: 5
# 100%|██████████| 5/5 [00:01<00:00,  2.96it/s]
#   Done 99 Posts; Elements: 2.909
#   Missing 1.922 Posts; Elements: 102.734
#
# Iteration 33: (2.7%) 0h 15m 17s
#   Using 3 Posts; Elements: 15
# 100%|██████████| 15/15 [00:04<00:00,  3.41it/s]
#   Done 102 Posts; Elements: 2.924
#   Missing 1.919 Posts; Elements: 102.719
#
# Iteration 34: (2.7%) 0h 15m 22s
#   Using 3 Posts; Elements: 8
# 100%|██████████| 8/8 [00:02<00:00,  3.12it/s]
#   Done 105 Posts; Elements: 2.932
#   Missing 1.916 Posts; Elements: 102.711
#
# Iteration 35: (2.7%) 0h 15m 26s
#   Using 3 Posts; Elements: 31
# 100%|██████████| 31/31 [00:09<00:00,  3.40it/s]
#   Done 108 Posts; Elements: 2.963
#   Missing 1.913 Posts; Elements: 102.680
#
# Iteration 36: (2.8%) 0h 15m 36s
#   Using 3 Posts; Elements: 211
# 100%|██████████| 211/211 [00:59<00:00,  3.57it/s]
#   Done 111 Posts; Elements: 3.174
#   Missing 1.910 Posts; Elements: 102.469
#
# Iteration 37: (3.0%) 0h 16m 35s
#   Using 3 Posts; Elements: 245
# 100%|██████████| 245/245 [01:08<00:00,  3.60it/s]
#   Done 114 Posts; Elements: 3.419
#   Missing 1.907 Posts; Elements: 102.224
#
# Iteration 38: (3.2%) 0h 17m 44s
#   Using 3 Posts; Elements: 132
# 100%|██████████| 132/132 [00:36<00:00,  3.63it/s]
#   Done 117 Posts; Elements: 3.551
#   Missing 1.904 Posts; Elements: 102.092
#
# Iteration 39: (3.3%) 0h 18m 21s
#   Using 3 Posts; Elements: 406
# 100%|██████████| 406/406 [01:50<00:00,  3.66it/s]
#   Done 120 Posts; Elements: 3.957
#   Missing 1.901 Posts; Elements: 101.686
#
# Iteration 40: (3.7%) 0h 20m 13s
#   Using 3 Posts; Elements: 675
# 100%|██████████| 675/675 [03:03<00:00,  3.68it/s]
#   Done 123 Posts; Elements: 4.632
#   Missing 1.898 Posts; Elements: 101.011
#
# Iteration 41: (4.3%) 0h 23m 18s
#   Using 3 Posts; Elements: 465
# 100%|██████████| 465/465 [02:06<00:00,  3.68it/s]
#   Done 126 Posts; Elements: 5.097
#   Missing 1.895 Posts; Elements: 100.546
#
# Iteration 42: (4.8%) 0h 25m 25s
#   Using 3 Posts; Elements: 123
# 100%|██████████| 123/123 [00:33<00:00,  3.67it/s]
#   Done 129 Posts; Elements: 5.220
#   Missing 1.892 Posts; Elements: 100.423
#
# Iteration 43: (4.9%) 0h 25m 59s
#   Using 3 Posts; Elements: 122
# 100%|██████████| 122/122 [00:33<00:00,  3.64it/s]
#   Done 132 Posts; Elements: 5.342
#   Missing 1.889 Posts; Elements: 100.301
#
# Iteration 44: (5.0%) 0h 26m 34s
#   Using 3 Posts; Elements: 235
# 100%|██████████| 235/235 [01:04<00:00,  3.64it/s]
#   Done 135 Posts; Elements: 5.577
#   Missing 1.886 Posts; Elements: 100.066
#
# Iteration 45: (5.2%) 0h 27m 39s
#   Using 3 Posts; Elements: 487
# 100%|██████████| 487/487 [02:12<00:00,  3.67it/s]
#   Done 138 Posts; Elements: 6.064
#   Missing 1.883 Posts; Elements: 99.579
#
# Iteration 46: (5.7%) 0h 29m 53s
#   Using 3 Posts; Elements: 404
# 100%|██████████| 404/404 [01:50<00:00,  3.64it/s]
#   Done 141 Posts; Elements: 6.468
#   Missing 1.880 Posts; Elements: 99.175
#
# Iteration 47: (6.1%) 0h 31m 45s
#   Using 3 Posts; Elements: 186
# 100%|██████████| 186/186 [00:51<00:00,  3.62it/s]
#   Done 144 Posts; Elements: 6.654
#   Missing 1.877 Posts; Elements: 98.989
#
# Iteration 48: (6.2%) 0h 32m 37s
#   Using 3 Posts; Elements: 110
# 100%|██████████| 110/110 [00:31<00:00,  3.52it/s]
#   Done 147 Posts; Elements: 6.764
#   Missing 1.874 Posts; Elements: 98.879
#
# Iteration 49: (6.4%) 0h 33m 9s
#   Using 3 Posts; Elements: 320
# 100%|██████████| 320/320 [01:28<00:00,  3.63it/s]
#   Done 150 Posts; Elements: 7.084
#   Missing 1.871 Posts; Elements: 98.559
#
# Iteration 50: (6.7%) 0h 34m 38s
#   Using 3 Posts; Elements: 869
# 100%|██████████| 869/869 [04:02<00:00,  3.59it/s]
#   Done 153 Posts; Elements: 7.953
#   Missing 1.868 Posts; Elements: 97.690
#
# Iteration 51: (7.5%) 0h 38m 41s
#   Using 3 Posts; Elements: 780
# 100%|██████████| 780/780 [03:34<00:00,  3.64it/s]
#   Done 156 Posts; Elements: 8.733
#   Missing 1.865 Posts; Elements: 96.910
#
# Iteration 52: (8.2%) 0h 42m 16s
#   Using 3 Posts; Elements: 384
# 100%|██████████| 384/384 [01:45<00:00,  3.64it/s]
#   Done 159 Posts; Elements: 9.117
#   Missing 1.862 Posts; Elements: 96.526
#
# Iteration 53: (8.6%) 0h 44m 3s
#   Using 3 Posts; Elements: 378
# 100%|██████████| 378/378 [01:43<00:00,  3.64it/s]
#   Done 162 Posts; Elements: 9.495
#   Missing 1.859 Posts; Elements: 96.148
#
# Iteration 54: (8.9%) 0h 45m 47s
#   Using 3 Posts; Elements: 207
# 100%|██████████| 207/207 [00:56<00:00,  3.65it/s]
#   Done 165 Posts; Elements: 9.702
#   Missing 1.856 Posts; Elements: 95.941
#
# Iteration 55: (9.1%) 0h 46m 44s
#   Using 3 Posts; Elements: 371
# 100%|██████████| 371/371 [01:41<00:00,  3.67it/s]
#   Done 168 Posts; Elements: 10.073
#   Missing 1.853 Posts; Elements: 95.570
#
# Iteration 56: (9.5%) 0h 48m 27s
#   Using 3 Posts; Elements: 577
# 100%|██████████| 577/577 [02:37<00:00,  3.67it/s]
#   Done 171 Posts; Elements: 10.650
#   Missing 1.850 Posts; Elements: 94.993
#
# Iteration 57: (10.0%) 0h 51m 6s
#   Using 3 Posts; Elements: 259
# 100%|██████████| 259/259 [01:10<00:00,  3.65it/s]
#   Done 174 Posts; Elements: 10.909
#   Missing 1.847 Posts; Elements: 94.734
#
# Iteration 58: (10.3%) 0h 52m 18s
#   Using 3 Posts; Elements: 243
# 100%|██████████| 243/243 [01:06<00:00,  3.67it/s]
#   Done 177 Posts; Elements: 11.152
#   Missing 1.844 Posts; Elements: 94.491
#
# Iteration 59: (10.5%) 0h 53m 25s
#   Using 3 Posts; Elements: 137
# 100%|██████████| 137/137 [00:37<00:00,  3.63it/s]
#   Done 180 Posts; Elements: 11.289
#   Missing 1.841 Posts; Elements: 94.354
#
# Iteration 60: (10.6%) 0h 54m 3s
#   Using 3 Posts; Elements: 219
# 100%|██████████| 219/219 [00:59<00:00,  3.66it/s]
#   Done 183 Posts; Elements: 11.508
#   Missing 1.838 Posts; Elements: 94.135
#
# Iteration 61: (10.8%) 0h 55m 4s
#   Using 3 Posts; Elements: 228
# 100%|██████████| 228/228 [01:02<00:00,  3.66it/s]
#   Done 186 Posts; Elements: 11.736
#   Missing 1.835 Posts; Elements: 93.907
#
# Iteration 62: (11.1%) 0h 56m 8s
#   Using 3 Posts; Elements: 446
# 100%|██████████| 446/446 [02:02<00:00,  3.65it/s]
#   Done 189 Posts; Elements: 12.182
#   Missing 1.832 Posts; Elements: 93.461
#
# Iteration 63: (11.5%) 0h 58m 11s
#   Using 3 Posts; Elements: 347
# 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#   Done 192 Posts; Elements: 12.529
#   Missing 1.829 Posts; Elements: 93.114
#
# Iteration 64: (11.8%) 0h 59m 47s
#   Using 3 Posts; Elements: 1.874
# 100%|██████████| 1874/1874 [08:47<00:00,  3.55it/s]
#   Done 195 Posts; Elements: 14.403
#   Missing 1.826 Posts; Elements: 91.240
#
# Iteration 65: (13.6%) 1h 8m 36s
#   Using 3 Posts; Elements: 302
# 100%|██████████| 302/302 [01:22<00:00,  3.67it/s]
#   Done 198 Posts; Elements: 14.705
#   Missing 1.823 Posts; Elements: 90.938
#
# Iteration 66: (13.9%) 1h 9m 59s
#   Using 3 Posts; Elements: 164
# 100%|██████████| 164/164 [00:44<00:00,  3.65it/s]
#   Done 201 Posts; Elements: 14.869
#   Missing 1.820 Posts; Elements: 90.774
#
# Iteration 67: (14.0%) 1h 10m 45s
#   Using 3 Posts; Elements: 146
# 100%|██████████| 146/146 [00:39<00:00,  3.68it/s]
#   Done 204 Posts; Elements: 15.015
#   Missing 1.817 Posts; Elements: 90.628
#
# Iteration 68: (14.2%) 1h 11m 26s
#   Using 3 Posts; Elements: 221
# 100%|██████████| 221/221 [01:00<00:00,  3.66it/s]
#   Done 207 Posts; Elements: 15.236
#   Missing 1.814 Posts; Elements: 90.407
#
# Iteration 69: (14.4%) 1h 12m 27s
#   Using 3 Posts; Elements: 103
# 100%|██████████| 103/103 [00:28<00:00,  3.62it/s]
#   Done 210 Posts; Elements: 15.339
#   Missing 1.811 Posts; Elements: 90.304
#
# Iteration 70: (14.5%) 1h 12m 56s
#   Using 3 Posts; Elements: 280
# 100%|██████████| 280/280 [01:16<00:00,  3.67it/s]
#   Done 213 Posts; Elements: 15.619
#   Missing 1.808 Posts; Elements: 90.024
#
# Iteration 71: (14.7%) 1h 14m 14s
#   Using 3 Posts; Elements: 341
# 100%|██████████| 341/341 [01:32<00:00,  3.70it/s]
#   Done 216 Posts; Elements: 15.960
#   Missing 1.805 Posts; Elements: 89.683
#
# Iteration 72: (15.1%) 1h 15m 47s
#   Using 3 Posts; Elements: 117
# 100%|██████████| 117/117 [00:32<00:00,  3.66it/s]
#   Done 219 Posts; Elements: 16.077
#   Missing 1.802 Posts; Elements: 89.566
#
# Iteration 73: (15.2%) 1h 16m 20s
#   Using 3 Posts; Elements: 105
# 100%|██████████| 105/105 [00:28<00:00,  3.68it/s]
#   Done 222 Posts; Elements: 16.182
#   Missing 1.799 Posts; Elements: 89.461
#
# Iteration 74: (15.3%) 1h 16m 50s
#   Using 3 Posts; Elements: 173
# 100%|██████████| 173/173 [00:47<00:00,  3.62it/s]
#   Done 225 Posts; Elements: 16.355
#   Missing 1.796 Posts; Elements: 89.288
#
# Iteration 75: (15.4%) 1h 17m 39s
#   Using 3 Posts; Elements: 289
#  75%|███████▍  | 216/289 [00:58<00:19,  3.71it/s]

# %% [markdown]
# #### Chunk Merging
#
# Once all predictions are done between all colab session, this function will allow to merge all the chunks into a single file, for optimizations of both space and speed.

# %%
def consolidate_chunks():
  total_posts, _ = merge_chunks()
  with open(f"{DRIVE_FOLDER}/Chunks/done.json", "w") as f:
    json.dump(total_posts, f)

# consolidate_chunks()

# %% [markdown]
# After the chunks have been consolidated, this line will remove all chunks avoiding the consolidates unified one.
#
# **IMPORTANT!!**: Just run this line once you are sure the consolidation was made correctly, if not the done data will be lost.

# %%
# Clean chunks
# !find  . -name 'sentiment_output_*' -exec rm {} \;

# %% [markdown]
# ### Training Phase
#
# This section will be focalized on training the model on the first place. Will be composed of an initial testing of the model without training, then a training phase, and at the end a final testing to check on the results of the training.

# %% [markdown]
# #### Dataset
#
# For the training and testing, we load the classified dataset of tweets.
# This dataset is sampled into equal parts for each emotion, 600 messages per emotion for training and other 600 per emotion for testing. For the validation, we keep 200 messages per emotion.
#
# Is important to note that the dataset includes a bigger quantity of messages, but due to the time requirements and the size of the LLM's used, they had to be restricted to be able to train the model accordingly, reducing training time from 15 hours to just 1.

# %%
df = load_dataset("SetFit/tweet_sentiment_extraction")
df = pd.DataFrame(df["train"])

X_train = list()
X_test = list()
for sentiment in ["positive", "neutral", "negative"]:
    train, test  = train_test_split(df[df.label_text==sentiment],
                                    train_size=600,
                                    test_size=600,
                                    random_state=42)
    X_train.append(train)
    X_test.append(test)

X_train = pd.concat(X_train).sample(frac=1, random_state=10)
X_test = pd.concat(X_test)

eval_idx = [idx for idx in df.index if idx not in list(train.index) + list(test.index)]
X_eval = df[df.index.isin(eval_idx)]
X_eval = (X_eval
          .groupby('label_text', group_keys=False)
          .apply(lambda x: x.sample(n=100, random_state=10, replace=True)))
X_train = X_train.reset_index(drop=True)

X_train = pd.DataFrame(X_train.apply(generate_prompt, axis=1), columns=["text"])
X_eval = pd.DataFrame(X_eval.apply(generate_prompt, axis=1), columns=["text"])

y_true = pd.DataFrame(X_test).label_text
X_test = pd.DataFrame(X_test.apply(generate_test_prompt, axis=1), columns=["text"])


train_data = Dataset.from_pandas(X_train)
eval_data = Dataset.from_pandas(X_eval)

print("Train:")
print(X_train)
print()
print("Test:")
print(X_test)

# %% [markdown]
# #### Initial Prediction with Untrained Model
#
# We use the prediction function to get the predicted emotions for the testing dataset.

# %%
y_pred = predict(X_test, model, tokenizer)
# Out:
# 100%|██████████| 1800/1800 [23:36<00:00,  1.27it/s]

# %% [markdown]
# And we analyse the results of the non-trained model.

# %%
evaluate(y_true, y_pred)
# Out:
# Accuracy: 0.772
# Accuracy for label 0: 0.808
# Accuracy for label 1: 0.692
# Accuracy for label 2: 0.815
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.81      0.80       600
#            1       0.68      0.69      0.69       600
#            2       0.85      0.81      0.83       600
#
#     accuracy                           0.77      1800
#    macro avg       0.77      0.77      0.77      1800
# weighted avg       0.77      0.77      0.77      1800
#
#
# Confusion Matrix:
# [[485  99  16]
#  [116 415  69]
#  [ 18  93 489]]

# %% [markdown]
# #### Text
#
# For further increasing the accuracy of the model, we fine-tune it with the training dataset. We define the loss function for the training, the validation function and the training parameters like steps, epochs, etc.
#
# We use the training data for the training process, and the validation data for a testing process of the improvement of the model, to know how it behaves between epochs and keep the weights with the best performance.

# %%
peft_config = LoraConfig(
    lora_alpha=16,
    lora_dropout=0,
    r=64,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj",
                    "gate_proj", "up_proj", "down_proj",],
)

training_arguments = TrainingArguments(
    output_dir="logs",
    num_train_epochs=3,
    gradient_checkpointing=True,
    per_device_train_batch_size=1,
    gradient_accumulation_steps=8,
    optim="paged_adamw_32bit",
    save_steps=0,
    logging_steps=25,
    learning_rate=2e-4,
    weight_decay=0.001,
    fp16=True,
    bf16=False,
    max_grad_norm=0.3,
    max_steps=-1,
    warmup_ratio=0.03,
    group_by_length=False,
    evaluation_strategy='steps',
    load_best_model_at_end=True,
    eval_steps = 112,
    eval_accumulation_steps=1,
    lr_scheduler_type="cosine",
    report_to="tensorboard",
)

trainer = SFTTrainer(
    model=model,
    train_dataset=train_data,
    eval_dataset=eval_data,
    peft_config=peft_config,
    dataset_text_field="text",
    tokenizer=tokenizer,
    max_seq_length=max_seq_length,
    args=training_arguments,
    packing=False,
)

# Train model
trainer.train()

# Save trained model
trainer.model.save_pretrained("trained-model")
# Out:
# Map:   0%|          | 0/15 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='3' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3/3 00:31, Epoch 1/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %% [markdown]
# #### Final Testing
#
# After training the model, we predict again the emotions of the testing dataset. We analyse the results to be able to compare the improvements of the model in comparison to the untrained model.

# %%
y_pred = predict(X_test, model, tokenizer)
# Out:
#   0%|          | 0/1800 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#   0%|          | 1/1800 [00:01<37:14,  1.24s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   0%|          | 2/1800 [00:01<26:32,  1.13it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   0%|          | 3/1800 [00:02<23:12,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   0%|          | 4/1800 [00:03<23:23,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   0%|          | 5/1800 [00:04<23:25,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   0%|          | 6/1800 [00:04<23:27,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   0%|          | 7/1800 [00:05<23:32,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   0%|          | 8/1800 [00:06<23:33,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   0%|          | 9/1800 [00:07<22:04,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 10/1800 [00:07<21:04,  1.42it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 11/1800 [00:08<20:23,  1.46it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 12/1800 [00:09<21:25,  1.39it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 13/1800 [00:09<22:03,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 14/1800 [00:10<22:32,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 15/1800 [00:11<21:28,  1.39it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 16/1800 [00:12<20:38,  1.44it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 17/1800 [00:12<21:32,  1.38it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 18/1800 [00:13<22:11,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 19/1800 [00:14<22:37,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 20/1800 [00:15<21:27,  1.38it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 21/1800 [00:15<22:08,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 22/1800 [00:16<22:35,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|▏         | 23/1800 [00:17<22:54,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|▏         | 24/1800 [00:18<21:41,  1.36it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|▏         | 25/1800 [00:18<22:15,  1.33it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|▏         | 26/1800 [00:19<22:43,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 27/1800 [00:20<22:58,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 28/1800 [00:21<23:08,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 29/1800 [00:21<21:51,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 30/1800 [00:22<22:25,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 31/1800 [00:23<22:46,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 32/1800 [00:24<23:03,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 33/1800 [00:25<23:14,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 34/1800 [00:25<21:55,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 35/1800 [00:26<21:03,  1.40it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 36/1800 [00:27<21:50,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 37/1800 [00:27<20:59,  1.40it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 38/1800 [00:28<21:51,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 39/1800 [00:29<22:23,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 40/1800 [00:30<22:44,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 41/1800 [00:31<23:04,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 42/1800 [00:31<23:14,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 43/1800 [00:32<21:50,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 44/1800 [00:33<22:25,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▎         | 45/1800 [00:34<22:51,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 46/1800 [00:35<23:11,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 47/1800 [00:35<23:25,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 48/1800 [00:36<23:34,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 49/1800 [00:37<23:44,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 50/1800 [00:38<23:48,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 51/1800 [00:39<23:51,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 52/1800 [00:39<23:56,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 53/1800 [00:40<22:25,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 54/1800 [00:41<22:49,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 55/1800 [00:42<23:09,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 56/1800 [00:43<23:21,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 57/1800 [00:43<22:00,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 58/1800 [00:44<21:02,  1.38it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 59/1800 [00:45<21:59,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 60/1800 [00:46<22:32,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 61/1800 [00:46<21:30,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 62/1800 [00:47<22:09,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▎         | 63/1800 [00:48<22:40,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▎         | 64/1800 [00:49<23:08,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▎         | 65/1800 [00:50<23:23,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▎         | 66/1800 [00:50<23:29,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▎         | 67/1800 [00:51<22:09,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 68/1800 [00:52<21:14,  1.36it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 69/1800 [00:52<20:34,  1.40it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 70/1800 [00:53<21:31,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 71/1800 [00:54<20:40,  1.39it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 72/1800 [00:55<21:36,  1.33it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 73/1800 [00:55<20:50,  1.38it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 74/1800 [00:56<21:48,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 75/1800 [00:57<22:24,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 76/1800 [00:58<22:48,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 77/1800 [00:59<23:11,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 78/1800 [00:59<23:26,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 79/1800 [01:00<22:04,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 80/1800 [01:01<22:39,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 81/1800 [01:02<21:35,  1.33it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 82/1800 [01:02<20:48,  1.38it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 83/1800 [01:03<21:48,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 84/1800 [01:04<22:27,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 85/1800 [01:05<22:52,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 86/1800 [01:06<23:12,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 87/1800 [01:06<23:24,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 88/1800 [01:07<22:05,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 89/1800 [01:08<22:45,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 90/1800 [01:09<23:09,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 91/1800 [01:10<23:25,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 92/1800 [01:11<23:35,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 93/1800 [01:11<22:15,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 94/1800 [01:12<21:14,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 95/1800 [01:13<22:05,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 96/1800 [01:13<21:08,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 97/1800 [01:14<21:58,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 98/1800 [01:15<21:04,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 99/1800 [01:16<20:30,  1.38it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 100/1800 [01:16<20:05,  1.41it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 101/1800 [01:17<19:48,  1.43it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 102/1800 [01:18<21:05,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 103/1800 [01:19<21:58,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 104/1800 [01:19<22:41,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 105/1800 [01:20<23:02,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 106/1800 [01:21<23:17,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 107/1800 [01:22<23:24,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 108/1800 [01:23<22:04,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 109/1800 [01:24<22:35,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 110/1800 [01:24<21:30,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 111/1800 [01:25<20:50,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 112/1800 [01:26<21:47,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▋         | 113/1800 [01:27<22:26,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▋         | 114/1800 [01:27<22:51,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▋         | 115/1800 [01:28<23:13,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▋         | 116/1800 [01:29<23:27,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▋         | 117/1800 [01:30<22:07,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 118/1800 [01:31<21:13,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 119/1800 [01:31<22:03,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 120/1800 [01:32<21:09,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 121/1800 [01:33<22:07,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 122/1800 [01:34<22:38,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 123/1800 [01:34<21:32,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 124/1800 [01:35<22:13,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 125/1800 [01:36<22:41,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 126/1800 [01:37<23:02,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 127/1800 [01:38<23:18,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 128/1800 [01:39<23:28,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 129/1800 [01:40<23:34,  1.18it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 130/1800 [01:40<22:10,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 131/1800 [01:41<22:38,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 132/1800 [01:42<21:30,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 133/1800 [01:43<22:16,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 134/1800 [01:44<22:43,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 135/1800 [01:44<23:00,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 136/1800 [01:45<23:10,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 137/1800 [01:46<23:20,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 138/1800 [01:47<21:57,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 139/1800 [01:48<22:30,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 140/1800 [01:49<22:50,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 141/1800 [01:49<21:34,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 142/1800 [01:50<22:13,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 143/1800 [01:51<22:36,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 144/1800 [01:52<22:49,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 145/1800 [01:52<21:34,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 146/1800 [01:53<22:09,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 147/1800 [01:54<21:07,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 148/1800 [01:55<21:49,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 149/1800 [01:56<22:15,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 150/1800 [01:57<22:35,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 151/1800 [01:57<22:56,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 152/1800 [01:58<23:05,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 153/1800 [01:59<23:06,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▊         | 154/1800 [02:00<23:12,  1.18it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▊         | 155/1800 [02:01<23:10,  1.18it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▊         | 156/1800 [02:02<23:12,  1.18it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▊         | 157/1800 [02:02<23:13,  1.18it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 158/1800 [02:03<21:48,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 159/1800 [02:04<20:47,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 160/1800 [02:05<21:29,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 161/1800 [02:06<21:58,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 162/1800 [02:06<20:48,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 163/1800 [02:07<20:08,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 164/1800 [02:08<21:03,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 165/1800 [02:08<20:08,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 166/1800 [02:09<21:01,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 167/1800 [02:10<21:39,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 168/1800 [02:11<20:40,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 169/1800 [02:12<21:19,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 170/1800 [02:12<20:28,  1.33it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|▉         | 171/1800 [02:13<21:13,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|▉         | 172/1800 [02:14<21:46,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|▉         | 173/1800 [02:15<20:40,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|▉         | 174/1800 [02:15<21:17,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|▉         | 175/1800 [02:16<20:21,  1.33it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|▉         | 176/1800 [02:17<21:08,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|▉         | 177/1800 [02:18<21:41,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|▉         | 178/1800 [02:19<20:34,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|▉         | 179/1800 [02:19<21:14,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 180/1800 [02:20<21:42,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 181/1800 [02:21<22:03,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 182/1800 [02:22<20:51,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 183/1800 [02:23<21:21,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 184/1800 [02:23<20:22,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 185/1800 [02:24<21:06,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 186/1800 [02:25<21:34,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 187/1800 [02:26<21:58,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 188/1800 [02:27<22:06,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 189/1800 [02:27<22:15,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 190/1800 [02:28<22:21,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 191/1800 [02:29<22:23,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 192/1800 [02:30<22:27,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 193/1800 [02:31<21:05,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 194/1800 [02:32<21:34,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 195/1800 [02:32<21:56,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 196/1800 [02:33<20:41,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 197/1800 [02:34<21:12,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 198/1800 [02:35<21:37,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 199/1800 [02:36<21:51,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 200/1800 [02:36<22:01,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 201/1800 [02:37<22:15,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 202/1800 [02:38<22:18,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█▏        | 203/1800 [02:39<22:27,  1.18it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█▏        | 204/1800 [02:40<22:25,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█▏        | 205/1800 [02:40<21:04,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█▏        | 206/1800 [02:41<20:08,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 207/1800 [02:42<20:49,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 208/1800 [02:43<19:48,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 209/1800 [02:44<20:39,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 210/1800 [02:44<21:12,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 211/1800 [02:45<20:10,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 212/1800 [02:46<20:50,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 213/1800 [02:47<21:17,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 214/1800 [02:48<21:37,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 215/1800 [02:48<20:27,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 216/1800 [02:49<19:36,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 217/1800 [02:50<20:28,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 218/1800 [02:50<19:41,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 219/1800 [02:51<20:29,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 220/1800 [02:52<21:07,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 221/1800 [02:53<21:32,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 222/1800 [02:54<21:49,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 223/1800 [02:55<22:02,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 224/1800 [02:56<22:08,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▎        | 225/1800 [02:56<22:13,  1.18it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 226/1800 [02:57<22:15,  1.18it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 227/1800 [02:58<22:14,  1.18it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 228/1800 [02:59<22:13,  1.18it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 229/1800 [03:00<22:15,  1.18it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 230/1800 [03:01<22:19,  1.17it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 231/1800 [03:02<22:14,  1.18it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 232/1800 [03:02<20:46,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 233/1800 [03:03<19:54,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 234/1800 [03:04<20:39,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 235/1800 [03:04<19:44,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 236/1800 [03:05<20:30,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 237/1800 [03:06<20:57,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 238/1800 [03:07<19:56,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 239/1800 [03:08<19:14,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 240/1800 [03:08<20:04,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 241/1800 [03:09<20:41,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 242/1800 [03:10<21:04,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▎        | 243/1800 [03:11<19:59,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▎        | 244/1800 [03:11<19:19,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▎        | 245/1800 [03:12<20:12,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▎        | 246/1800 [03:13<19:23,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▎        | 247/1800 [03:14<18:53,  1.37it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 248/1800 [03:14<18:29,  1.40it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 249/1800 [03:15<18:09,  1.42it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 250/1800 [03:16<19:19,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 251/1800 [03:17<20:07,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 252/1800 [03:18<20:40,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 253/1800 [03:18<21:05,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 254/1800 [03:19<19:59,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 255/1800 [03:20<20:34,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 256/1800 [03:21<20:58,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 257/1800 [03:22<21:14,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 258/1800 [03:22<21:24,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 259/1800 [03:23<20:08,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 260/1800 [03:24<20:38,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 261/1800 [03:25<20:55,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▍        | 262/1800 [03:26<19:50,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▍        | 263/1800 [03:26<20:30,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▍        | 264/1800 [03:27<19:30,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▍        | 265/1800 [03:28<18:49,  1.36it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▍        | 266/1800 [03:28<18:22,  1.39it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▍        | 267/1800 [03:29<18:02,  1.42it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▍        | 268/1800 [03:30<19:10,  1.33it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▍        | 269/1800 [03:31<19:54,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▌        | 270/1800 [03:31<19:06,  1.33it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▌        | 271/1800 [03:32<19:49,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▌        | 272/1800 [03:33<20:18,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▌        | 273/1800 [03:34<19:21,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▌        | 274/1800 [03:35<20:02,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▌        | 275/1800 [03:36<20:30,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▌        | 276/1800 [03:36<19:28,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▌        | 277/1800 [03:37<20:07,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▌        | 278/1800 [03:38<20:33,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 279/1800 [03:39<19:30,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 280/1800 [03:39<20:08,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 281/1800 [03:40<20:32,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 282/1800 [03:41<19:30,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 283/1800 [03:42<20:04,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 284/1800 [03:43<20:27,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 285/1800 [03:44<20:46,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 286/1800 [03:44<20:58,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 287/1800 [03:45<21:06,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 288/1800 [03:46<19:49,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 289/1800 [03:47<20:15,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 290/1800 [03:48<20:35,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 291/1800 [03:48<19:29,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 292/1800 [03:49<20:05,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▋        | 293/1800 [03:50<19:05,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▋        | 294/1800 [03:51<19:42,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▋        | 295/1800 [03:51<18:53,  1.33it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▋        | 296/1800 [03:52<19:36,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▋        | 297/1800 [03:53<20:06,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 298/1800 [03:54<19:04,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 299/1800 [03:55<19:43,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 300/1800 [03:55<20:09,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 301/1800 [03:56<20:30,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 302/1800 [03:57<19:21,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 303/1800 [03:58<19:53,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 304/1800 [03:58<18:59,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 305/1800 [03:59<19:41,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 306/1800 [04:00<20:10,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 307/1800 [04:01<19:03,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 308/1800 [04:02<19:40,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 309/1800 [04:02<20:02,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 310/1800 [04:03<20:21,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 311/1800 [04:04<19:13,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 312/1800 [04:05<18:28,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 313/1800 [04:06<19:11,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 314/1800 [04:06<19:43,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 315/1800 [04:07<20:09,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 316/1800 [04:08<20:22,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 317/1800 [04:09<20:32,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 318/1800 [04:10<19:27,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 319/1800 [04:10<19:57,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 320/1800 [04:11<20:16,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 321/1800 [04:12<20:29,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 322/1800 [04:13<20:38,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 323/1800 [04:14<20:41,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 324/1800 [04:15<20:42,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 325/1800 [04:16<20:44,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 326/1800 [04:16<20:42,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 327/1800 [04:17<19:25,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 328/1800 [04:18<19:51,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 329/1800 [04:19<20:07,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 330/1800 [04:20<20:21,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 331/1800 [04:20<20:28,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 332/1800 [04:21<19:17,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 333/1800 [04:22<19:45,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▊        | 334/1800 [04:23<20:02,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▊        | 335/1800 [04:24<20:16,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▊        | 336/1800 [04:24<19:06,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▊        | 337/1800 [04:25<18:19,  1.33it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 338/1800 [04:26<19:00,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 339/1800 [04:27<19:27,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 340/1800 [04:27<18:30,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 341/1800 [04:28<17:52,  1.36it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 342/1800 [04:29<18:42,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 343/1800 [04:30<19:17,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 344/1800 [04:30<18:21,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 345/1800 [04:31<19:01,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 346/1800 [04:32<19:27,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 347/1800 [04:33<19:43,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 348/1800 [04:34<19:58,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 349/1800 [04:35<18:51,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 350/1800 [04:35<18:04,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|█▉        | 351/1800 [04:36<18:50,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|█▉        | 352/1800 [04:37<18:01,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|█▉        | 353/1800 [04:37<17:29,  1.38it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|█▉        | 354/1800 [04:38<18:24,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|█▉        | 355/1800 [04:39<18:59,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|█▉        | 356/1800 [04:40<19:26,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|█▉        | 357/1800 [04:41<19:42,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|█▉        | 358/1800 [04:41<18:38,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|█▉        | 359/1800 [04:42<19:06,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|██        | 360/1800 [04:43<18:14,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|██        | 361/1800 [04:44<17:37,  1.36it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|██        | 362/1800 [04:45<18:22,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|██        | 363/1800 [04:45<17:42,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|██        | 364/1800 [04:46<17:13,  1.39it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|██        | 365/1800 [04:47<16:52,  1.42it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|██        | 366/1800 [04:47<17:52,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|██        | 367/1800 [04:48<18:33,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|██        | 368/1800 [04:49<19:03,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|██        | 369/1800 [04:50<18:12,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 370/1800 [04:50<17:35,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 371/1800 [04:51<18:23,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 372/1800 [04:52<17:40,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 373/1800 [04:53<18:24,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 374/1800 [04:54<18:56,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 375/1800 [04:54<18:01,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 376/1800 [04:55<17:24,  1.36it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 377/1800 [04:56<18:17,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 378/1800 [04:57<18:49,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 379/1800 [04:58<19:12,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 380/1800 [04:58<18:14,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 381/1800 [04:59<17:33,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 382/1800 [05:00<17:06,  1.38it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██▏       | 383/1800 [05:00<18:03,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██▏       | 384/1800 [05:01<18:37,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██▏       | 385/1800 [05:02<18:58,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██▏       | 386/1800 [05:03<19:17,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  22%|██▏       | 387/1800 [05:04<18:13,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  22%|██▏       | 388/1800 [05:04<17:30,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ...
#  93%|█████████▎| 1676/1800 [21:59<01:33,  1.33it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 1677/1800 [22:00<01:36,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 1678/1800 [22:01<01:31,  1.33it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 1679/1800 [22:02<01:28,  1.37it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 1680/1800 [22:02<01:31,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 1681/1800 [22:03<01:33,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 1682/1800 [22:04<01:34,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▎| 1683/1800 [22:05<01:35,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▎| 1684/1800 [22:06<01:36,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▎| 1685/1800 [22:07<01:36,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▎| 1686/1800 [22:07<01:29,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▎| 1687/1800 [22:08<01:31,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 1688/1800 [22:09<01:25,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 1689/1800 [22:10<01:22,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 1690/1800 [22:10<01:24,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 1691/1800 [22:11<01:26,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 1692/1800 [22:12<01:27,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 1693/1800 [22:13<01:28,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 1694/1800 [22:14<01:27,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 1695/1800 [22:15<01:27,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 1696/1800 [22:16<01:27,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 1697/1800 [22:16<01:21,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 1698/1800 [22:17<01:22,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 1699/1800 [22:18<01:17,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 1700/1800 [22:18<01:14,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 1701/1800 [22:19<01:16,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▍| 1702/1800 [22:20<01:18,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▍| 1703/1800 [22:21<01:13,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▍| 1704/1800 [22:22<01:15,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▍| 1705/1800 [22:23<01:16,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▍| 1706/1800 [22:23<01:16,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▍| 1707/1800 [22:24<01:17,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▍| 1708/1800 [22:25<01:12,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▍| 1709/1800 [22:26<01:13,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 1710/1800 [22:26<01:08,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 1711/1800 [22:27<01:10,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 1712/1800 [22:28<01:10,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 1713/1800 [22:29<01:11,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 1714/1800 [22:30<01:06,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 1715/1800 [22:30<01:07,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 1716/1800 [22:31<01:03,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 1717/1800 [22:32<01:01,  1.36it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 1718/1800 [22:32<00:58,  1.39it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 1719/1800 [22:33<01:01,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 1720/1800 [22:34<01:02,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 1721/1800 [22:35<00:59,  1.33it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 1722/1800 [22:36<01:01,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 1723/1800 [22:37<01:02,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 1724/1800 [22:37<01:02,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 1725/1800 [22:38<01:02,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 1726/1800 [22:39<00:57,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 1727/1800 [22:40<00:54,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 1728/1800 [22:41<00:56,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 1729/1800 [22:41<00:56,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 1730/1800 [22:42<00:57,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 1731/1800 [22:43<00:56,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 1732/1800 [22:44<00:56,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▋| 1733/1800 [22:45<00:56,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▋| 1734/1800 [22:46<00:55,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▋| 1735/1800 [22:46<00:51,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▋| 1736/1800 [22:47<00:51,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▋| 1737/1800 [22:48<00:51,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 1738/1800 [22:49<00:51,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 1739/1800 [22:50<00:50,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 1740/1800 [22:50<00:50,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 1741/1800 [22:51<00:46,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 1742/1800 [22:52<00:43,  1.32it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 1743/1800 [22:53<00:44,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 1744/1800 [22:54<00:44,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 1745/1800 [22:54<00:44,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 1746/1800 [22:55<00:44,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 1747/1800 [22:56<00:41,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 1748/1800 [22:57<00:41,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 1749/1800 [22:58<00:41,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 1750/1800 [22:58<00:38,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 1751/1800 [22:59<00:38,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 1752/1800 [23:00<00:38,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 1753/1800 [23:01<00:38,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 1754/1800 [23:02<00:35,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 1755/1800 [23:02<00:33,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 1756/1800 [23:03<00:34,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 1757/1800 [23:04<00:32,  1.34it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 1758/1800 [23:04<00:30,  1.37it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 1759/1800 [23:05<00:31,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 1760/1800 [23:06<00:29,  1.36it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 1761/1800 [23:07<00:30,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 1762/1800 [23:07<00:28,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 1763/1800 [23:08<00:28,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 1764/1800 [23:09<00:28,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 1765/1800 [23:10<00:28,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 1766/1800 [23:11<00:26,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 1767/1800 [23:12<00:26,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 1768/1800 [23:12<00:26,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 1769/1800 [23:13<00:23,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 1770/1800 [23:14<00:23,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 1771/1800 [23:15<00:23,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 1772/1800 [23:16<00:23,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 1773/1800 [23:16<00:22,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▊| 1774/1800 [23:17<00:20,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▊| 1775/1800 [23:18<00:20,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▊| 1776/1800 [23:19<00:18,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▊| 1777/1800 [23:19<00:17,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 1778/1800 [23:20<00:15,  1.39it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 1779/1800 [23:21<00:14,  1.41it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 1780/1800 [23:21<00:13,  1.43it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 1781/1800 [23:22<00:13,  1.45it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 1782/1800 [23:23<00:13,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 1783/1800 [23:24<00:12,  1.39it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 1784/1800 [23:24<00:12,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 1785/1800 [23:25<00:11,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 1786/1800 [23:26<00:11,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 1787/1800 [23:27<00:10,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 1788/1800 [23:28<00:09,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 1789/1800 [23:29<00:08,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 1790/1800 [23:29<00:08,  1.24it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 1791/1800 [23:30<00:06,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 1792/1800 [23:31<00:05,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 1793/1800 [23:32<00:05,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 1794/1800 [23:32<00:04,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 1795/1800 [23:33<00:04,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 1796/1800 [23:34<00:03,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 1797/1800 [23:35<00:02,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 1798/1800 [23:36<00:01,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 1799/1800 [23:36<00:00,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 1800/1800 [23:37<00:00,  1.27it/s]
# Accuracy: 0.700
# Accuracy for label 0: 0.758
# Accuracy for label 1: 0.592
# Accuracy for label 2: 0.750
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.76      0.75       600
#            1       0.60      0.59      0.60       600
#            2       0.76      0.75      0.75       600
#
#     accuracy                           0.70      1800
#    macro avg       0.70      0.70      0.70      1800
# weighted avg       0.70      0.70      0.70      1800
#
#
# Confusion Matrix:
# [[455 116  29]
#  [131 355 114]
#  [ 32 118 450]]

# %%
evaluate(y_true, y_pred)

# %% [markdown]
# # Extra space for developing
