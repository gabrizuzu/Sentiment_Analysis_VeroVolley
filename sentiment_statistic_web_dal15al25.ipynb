# %% [markdown]
# <a href="https://colab.research.google.com/github/nachobascar/VeroVolley-Group-2/blob/main/sentiment_statistic_web_dal15al25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

with open('output_with_web.json', 'r') as f:
    data = json.load(f)

# %%
posts = data
posts

# %%
filtered_data = []
count_post = 0

for post in posts:
    comments = post['comments']
    filtered_post = {
        'link': post['link'],
        'sentiment': post['sentiment'],
        'comments' : [{'sentiment': comment['sentiment']} for comment in comments]
    }
    filtered_data.append(filtered_post)
    count_post = count_post + 1

filtered_data
# Out:
# [{'link': 'https://dal15al25.gazzetta.it/2024/03/31/video-trento-verso-gara-1-con-monza/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/31/supervolley-in-edicola-4/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/31/le-altre-gare-di-semifinale/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/28/a-pasqua-con-gara-1-di-semifinale/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/27/gli-spareggi-dei-quarti-maschili/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/27/milano-e-monza-ancora-una-semifinale/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/27/chieri-sbanca-ancora-novara/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/27/monza-e-milano-non-sono-piu-una-sorpresa/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'negative'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/26/civitanova-chi-resta-e-chi-va/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/25/il-programma-delle-semifinali-2/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/26/a-carugate-linaugurazione-del-progetto-sociale-europeo-advanage/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/24/mercoledi-gara-5-a-civitanova/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/24/video-dopo-monza-civitanova/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/24/piacenza-e-monza-con-il-match-ball/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/24/il-gran-colpo-di-firenze/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/25/mercoledi-gli-spareggi-a-civitanova-e-piacenza/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/21/la-gioia-di-fabris-per-il-tris-italiano/',
#   'sentiment': 'positive',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/21/egonu-nostra-signora-della-champions/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'positive'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/19/milano-in-finale-di-champions/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'positive'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/19/i-35-punti-di-egonu-i-29-di-vargas/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'positive'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/20/video-egonu-dopo-la-semifinale-di-ritorno/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'positive'}, {'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/20/video-yant-verso-champions-e-gara-4-a-monza/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/17/perugia-in-semifinale-la-lube-riapre-la-serie/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'negative'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/18/la-situazione-in-superlega-dopo-gara-3/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/16/il-record-di-padova/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/16/si-gioca-a-piacenza/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/16/trento-fa-un-altro-colpo/',
#   'sentiment': 'positive',
#   'comments': [{'sentiment': 'negative'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/12/serata-clou-per-milano/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/12/video-interviste-rai-dopo-monza-civitanova/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/10/cachopa-trascina-monza-sul-2-0/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/10/takahashi-trascinatore-lube-sotto-2-0/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/10/sabato-e-domenica-gara-3/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/11/video-blengini-dopo-monza/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/09/rohrs-insegue-rohrs/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/09/zaytsev-torna-a-disposizione/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'positive'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/09/il-programma-di-gara-2-serie-al-meglio-delle-5/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/09/firenze-sbanca-chieri/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/10/antropova-trascina-scandicci/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'positive'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/08/il-programma-di-gara-2/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'neutral'}, {'sentiment': 'positive'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/08/il-programma-di-gara-3-2/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/09/festival-del-bene-comune/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/07/casalmaggiore-che-colpo-con-milano/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/12/milano-3-0-al-fener/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/07/monza-e-milano-fanno-il-colpo/',
#   'sentiment': 'positive',
#   'comments': [{'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'positive'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/07/casalmaggiore-abbatte-milano/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/04/il-miracolo-di-cuccarini-a-roma/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/03/milano-supera-roma-al-tiebreak/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/03/cuneo-successo-importante/',
#   'sentiment': 'positive',
#   'comments': [{'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/03/catania-saluta-la-superlega-con-una-vittoria/',
#   'sentiment': 'positive',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/03/02/lultima-di-superlega-4/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/02/29/folie-13-diouf-15/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/02/27/varsavia-vince-la-challengecup/',
#   'sentiment': 'positive',
#   'comments': [{'sentiment': 'negative'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/02/28/il-valore-di-italia-e-polonia/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/02/26/monza-ritorno-di-finale-con-varsavia/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/02/27/domenica-lultima-di-superlega/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'neutral'}, {'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/02/25/spareggio-terzo-posto-a-civitanova/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/02
',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2023/10/29/perugia-supera-3-0-monza/',
#   'sentiment': 'positive',
#   'comments': [{'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2023/10/29/video-semenik-e-takahashi-dopo-monza-perugia/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2023/11/19/video-le-interviste-dopo-trento-monza/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2023/11/19/herrera-e-peric-ingressi-decisivi/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'neutral'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/01/05/le-final-four-di-coppa-italia-a-fine-gennaio-a-bologna/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/01/10/i-biglietti-per-le-final-four-di-bologna/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/01/16/i-20-punti-di-egonu-2/',
#   'sentiment': 'neutral',
#   'comments': [{'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'negative'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'},
#    {'sentiment': 'neutral'},
#    {'sentiment': 'positive'}]},
#  {'link': 'https://dal15al25.gazzetta.it/2024/01/17/monza-turnover-e-vittoria/',
#   'sentiment': 'positive',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/01/21/tutto-facile-per-monza-4/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/01/24/non-basta-buchegger-a-catania/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/02/04/video-le-parole-di-trento-dopo-monza-3/',
#   'sentiment': 'neutral',
#   'comments': []},
#  {'link': 'https://dal15al25.gazzetta.it/2024/02/16/nel-weekend-si-gioca-la-decima-di-superlega/',
#   'sentiment': 'neutral',
#   'comments': []}]

# %%
count_post
# Out:
# 317

# %%
count_pos = 0
count_neg = 0
count_neu = 0

for item in filtered_data:
    if item.get('sentiment') == 'positive':
        count_pos = count_pos + 1

    if item.get('sentiment') == 'negative':
        count_neg = count_neg + 1

    if item.get('sentiment') == 'neutral':
        count_neu = count_neu + 1

print('Sentiment positive: ', count_pos)
print('Sentiment negative: ', count_neg)
print('Sentiment neutral: ', count_neu)
# Out:
# Sentiment positive:  14
# Sentiment negative:  5
# Sentiment neutral:  298

# %%
import matplotlib.pyplot as plt

labels = ['Positive', 'Negative', 'Neutral']
values = [count_pos, count_neg, count_neu]

bars = plt.bar(labels, values, color=['green', 'red', 'blue'], width = 0.5)

for bar, value in zip(bars, values):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height(), value, ha='center', va='bottom', fontsize=8, color='black', weight='bold')

plt.xlabel('Type of sentiment', fontsize=10, weight='bold')
plt.ylabel('Values', fontsize=10, weight='bold')
plt.title('SENTIMENTAL ANALYSIS STATISTICS - NEWSPAPERS', fontsize=14)

plt.show()

# %%
count_pos = 0
count_neg = 0
count_neu = 0

count_comments = 0

for item in filtered_data:
    comments = item.get('comments', [])
    for comment in comments:
        sentiment = comment.get('sentiment')
        if sentiment == 'positive':
            count_pos = count_pos + 1
        if sentiment == 'negative':
            count_neg = count_neg + 1
        if sentiment == 'neutral':
            count_neu = count_neu + 1
        count_comments = count_comments + 1

print('Sentiment positive: ', count_pos)
print('Sentiment negative: ', count_neg)
print('Sentiment neutral: ', count_neu)
# Out:
# Sentiment positive:  117
# Sentiment negative:  323
# Sentiment neutral:  972

# %%
count_comments
# Out:
# 1413

# %%
import matplotlib.pyplot as plt

labels = ['Positive', 'Negative', 'Neutral']
values = [count_pos, count_neg, count_neu]

bars = plt.bar(labels, values, color=['green', 'red', 'blue'], width = 0.5)

for bar, value in zip(bars, values):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height(), value, ha='center', va='bottom', fontsize=8, color='black', weight='bold')

plt.xlabel('Type of sentiment', fontsize=10, weight='bold')
plt.ylabel('Values', fontsize=10, weight='bold')
plt.title('SENTIMENTAL ANALYSIS STATISTICS - COMMENTS', fontsize=14)

plt.show()
